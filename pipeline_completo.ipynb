# %% [markdown]
# <a href="https://colab.research.google.com/github/Arthur281106/Atividade-Condicionais/blob/main/pipeline_completo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = ""

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "imtkaggleteam/mental-health",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# /tmp/ipykernel_983/4214788610.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_983/4214788610.py in <cell line: 0>()
#       8
#       9 # Load the latest version
# ---> 10 df = kagglehub.load_dataset(
#      11   KaggleDatasetAdapter.PANDAS,
#      12   "imtkaggleteam/mental-health",
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/datasets.py in load_dataset(adapter, handle, path, pandas_kwargs, sql_query, hf_kwargs)
#     190         stacklevel=2,
#     191     )
# --> 192     return dataset_load(adapter, handle, path, pandas_kwargs=pandas_kwargs, sql_query=sql_query, hf_kwargs=hf_kwargs)
#     193
#     194
#
# ...
